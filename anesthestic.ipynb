# %%
# %matplotlib inline
from anesthetic import MCMCSamples
from anesthetic import NestedSamples

# %%
mcmc_root = '/home/isidro/SimpleMC/chains/LCDM_phy_BBAO+HD_nested_dynesty_multi'
mcmc = MCMCSamples(root=mcmc_root)

# %%
fig, axes = mcmc.plot_1d('Om')

# %%
fig, axes = mcmc.plot_1d(['Om','Obh2','h']);
fig.tight_layout()

# %%
mcmc.plot_2d(['Om','Obh2','h'], types={'lower':'kde','diagonal':'kde'});

# %%
mcmc.plot_2d(['Om','Obh2','h'])
# Out:
# (<Figure size 432x288 with 12 Axes>,
#                                                    Om  \
#  Om    DiagonalAxes(0.125,0.628333;0.258333x0.251667)
#  Obh2   AxesSubplot(0.125,0.376667;0.258333x0.251667)
#  h         AxesSubplot(0.125,0.125;0.258333x0.251667)
#
#                                                     Obh2  \
#  Om     AxesSubplot(0.383333,0.628333;0.258333x0.251667)
#  Obh2  DiagonalAxes(0.383333,0.376667;0.258333x0.251667)
#  h         AxesSubplot(0.383333,0.125;0.258333x0.251667)
#
#                                                       h
#  Om    AxesSubplot(0.641667,0.628333;0.258333x0.251667)
#  Obh2  AxesSubplot(0.641667,0.376667;0.258333x0.251667)
#  h       DiagonalAxes(0.641667,0.125;0.258333x0.251667)  )

# %%
mcmc.plot_2d([['Om','h'], ['Om','Obh2']])
# Out:
# (<Figure size 432x288 with 5 Axes>,
#                                              Om  \
#  Om    DiagonalAxes(0.125,0.5025;0.3875x0.3775)
#  Obh2    AxesSubplot(0.125,0.125;0.3875x0.3775)
#
#                                               h
#  Om    AxesSubplot(0.5125,0.5025;0.3875x0.3775)
#  Obh2   AxesSubplot(0.5125,0.125;0.3875x0.3775)  )

# %% [markdown]
# Nested

# %%
nested_root = '/home/isidro/SimpleMC/chains/LCDM_phy_BBAO_emcee_ensambles_20'
nested = NestedSamples(root=nested_root)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_blocks(blocks, axes)
#    1677                 blocks = [
# -> 1678                     make_block(values=blocks[0], placement=slice(0, len(axes[0])))
#    1679                 ]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3283
# -> 3284     return klass(values, ndim=ndim, placement=placement)
#    3285
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     127                 "Wrong number of items passed {val}, placement implies "
# --> 128                 "{mgr}".format(val=len(self.values), mgr=len(self.mgr_locs))
#     129             )
#
# ...

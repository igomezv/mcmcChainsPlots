# %%
import corner
import numpy as np

# %%
chaindir = '/home/isidro/SuperMC/chains/'
chainname = 'owaCDM_pySN+HD+BBAO_snest_0.6.txt'
#npchain = np.asanyarray(np.loadtxt(chaindir+chainname))
outputname = chaindir+chainname
npchain = np.loadtxt(outputname)

# %%
np.shape(npchain)
# Out:
# (1396, 8)

# %%
chain = npchain[:,2:]
np.shape(chain)
# Out:
# (1396, 6)

# %%
figure = corner.corner(chain)

# %%
figure = corner.corner(chain, labels=["$\Omega_m$", "$\Omega_bh^2$", "$h$","$\omega$","$\omega_a$","$\Omega_k$"],
                       bins = 20,
                       weights = None,
                       color='g',
                       quantiles=[0.5],
                       show_titles=True, 
                       title_fmt = '.4f',
                       smooth=True, 
                       fill_contours = True,
                       title_kwargs={"fontsize": 12})
#figure.savefig("corner.png")

# %%
chainname = 'owaCDM_pySN+HD+BBAO_mnest_0.6.txt'
#npchain = np.asanyarray(np.loadtxt(chaindir+chainname))
outputname = chaindir+chainname
npchain = np.loadtxt(outputname)
chain = npchain[:,2:]
figure = corner.corner(chain, labels=["$\Omega_m$", "$\Omega_bh^2$", "$h$","$\omega$","$\omega_a$","$\Omega_k$"],
                       bins = 20,
                       weights = None,
                       color='g',
                       quantiles=[0.5],
                       show_titles=True, 
                       title_fmt = '.4f',
                       smooth=True, 
                       fill_contours = True,
                       title_kwargs={"fontsize": 12})

# %%
chainname = 'owaCDM_pySN+HD+BBAO_sbambi_0.6.txt'
#npchain = np.asanyarray(np.loadtxt(chaindir+chainname))
outputname = chaindir+chainname
npchain = np.loadtxt(outputname)
chain = npchain[:,2:]
figure = corner.corner(chain, labels=["$\Omega_m$", "$\Omega_bh^2$", "$h$","$\omega$","$\omega_a$","$\Omega_k$"],
                       bins = 20,
                       weights = None,
                       color='g',
                       quantiles=[0.5],
                       show_titles=True, 
                       title_fmt = '.4f',
                       smooth=True, 
                       fill_contours = True,
                       title_kwargs={"fontsize": 12})

# %%
chainname = 'owaCDM_pySN+HD+BBAO_bambi_0.6.txt'
#npchain = np.asanyarray(np.loadtxt(chaindir+chainname))
outputname = chaindir+chainname
npchain = np.loadtxt(outputname)
chain = npchain[:,2:]
figure = corner.corner(chain, labels=["$\Omega_m$", "$\Omega_bh^2$", "$h$","$\omega$","$\omega_a$","$\Omega_k$"],
                       bins = 20,
                       weights = None,
                       color='g',
                       quantiles=[0.5],
                       show_titles=True, 
                       title_fmt = '.4f',
                       smooth=True, 
                       fill_contours = True,
                       title_kwargs={"fontsize": 12})

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots, MCSamples, mcsamples
from getdist import *
#import getdist
#import planckStyle
import pylab
import numpy as np

# %%
#dir_name = '/home/isidro/SuperMC/chains/owaChains2'
dir_name = '/home/isidro/SuperMC/chains'

roots = ['owaCDM_py_SN+BBAO+RiessH0_mh_50000_1', 'owaCDM_SN+BBAO+RiessH0_snest_0.6', 'owaCDM_SN+BBAO+RiessH0_mnest_0.6',
        'owaCDM_SN+BBAO+RiessH0_sbambi_0.6', 'owaCDM_SN+BBAO+RiessH0_bambi_0.6']

roots2 = ['owaCDM_py_SN+HD+BBAO_mh_50000_1', 'owaCDM_SN+HD+BBAO_snest_0.6', 'owaCDM_SN+HD+BBAO_mnest_0.6',
        'owaCDM_SN+HD+BBAO_sbambi_0.6', 'owaCDM_SN+HD+BBAO_bambi_0.6']

roots3 = ['owaCDM_py_SN+HD+BBAO_mh_500000_1', 'owaCDM_pySN+HD+BBAO_snest_0.6', 
        'owaCDM_pySN+HD+BBAO_mnest_0.6',
        'owaCDM_pySN+HD+BBAO_sbambi_0.6', 'owaCDM_pySN+HD+BBAO_bambi_0.6']

# %%
g= plots.getSinglePlotter(chain_dir = dir_name, width_inch=10,
                          analysis_settings={'smooth_scale_2D': 0.8,'smooth_scale_1D': 0.3, 'ignore_rows': 0.3})

# %%
#g.plot_2d(root,'Om','Obh2', filled=False, nx=1, alphas=[0.9], colors=['blue','red'])
g.settings.lab_fontsize = 15
g.settings.alpha_filled_add = 0.9
g.settings.legend_fontsize= 12
g.settings.colorbar_axes_fontsize = 20
g.settings.scatter_size = 9
g.settings.lw_contour = 3
g.settings.auto_ticks = 1
g.plot_2d(roots2,'Om','Obh2', filled=False, nx=1, alphas=[0.9])
#g.add_text('$k_{eq}=0.0152$', x=0.27, y=0.15, fontsize =13)
g.add_legend(['mh', 'snest','mnest','sbambi','bambi'], 
             colored_text=True,  legend_loc='upper right')
#plt.savefig('a.png')
# Out:
# /home/isidro/SuperMC/chains/owaCDM_py_SN+HD+BBAO_mh_50000_1.txt
# Error reading /home/isidro/SuperMC/chains/owaCDM_py_SN+HD+BBAO_mh_50000_1.txt
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-10-1a1773c981a4> in <module>
#       7 g.settings.lw_contour = 3
#       8 g.settings.auto_ticks = 1
# ----> 9 g.plot_2d(roots2,'Om','Obh2', filled=False, nx=1, alphas=[0.9])
#      10 #g.add_text('$k_{eq}=0.0152$', x=0.27, y=0.15, fontsize =13)
#      11 g.add_legend(['mh', 'snest','mnest','sbambi','bambi'],
#
# /usr/local/lib/python3.6/dist-packages/getdist/plots.py in plot_2d(self, roots, param1, param2, param_pair, shaded, add_legend_proxy, line_offset, proxy_root_exclude, **kwargs)
#    1151             param_pair = param1
#    1152             param1 = None
# -> 1153         param_pair = self.get_param_array(roots[0], param_pair or [param1, param2])
# ...

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 12
g.settings.alpha_filled_add = 0.2
g.settings.legend_fontsize= 12
g.settings.colorbar_axes_fontsize = 10
g.settings.scatter_size = 9
g.settings.lw_contour = 3
g.settings.auto_ticks = 10
g.settings.axes_fontsize = 8

#g.settings.colormap_scatter='spring'
g.triangle_plot(roots2, ['Om', 'Obh2', 'h','w','wa','Ok'], diag1d_kwargs={'colors':['red','blue','black','green','yellow']},
                filled=False, nx=1, alphas=[0.7], colors=['red','blue','black','green','yellow'],
               legend_labels=['MH', 'ENS', 'MULTINEST', 'ENS+ANN', 'BAMBI'], 
                normalized=False, shaded=True)



#plt.savefig('samplersTriangleB.png')
# Out:
# /home/isidro/SuperMC/chains/owaCDM_py_SN+HD+BBAO_mh_50000_1.txt
# Error reading /home/isidro/SuperMC/chains/owaCDM_py_SN+HD+BBAO_mh_50000_1.txt
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-6-a9ed067b6b25> in <module>
#      13                 filled=False, nx=1, alphas=[0.7], colors=['red','blue','black','green','yellow'],
#      14                legend_labels=['MH', 'ENS', 'MULTINEST', 'ENS+ANN', 'BAMBI'],
# ---> 15                 normalized=False, shaded=True)
#      16
#      17
#
# /usr/local/lib/python3.6/dist-packages/getdist/plots.py in triangle_plot(self, roots, params, legend_labels, plot_3d_with_param, filled, shaded, contour_args, contour_colors, contour_ls, contour_lws, line_args, label_order, legend_ncol, legend_loc, upper_roots, upper_kwargs, diag1d_kwargs, param_limits, **kwargs)
#    1951         """
# ...

# %%
rootU=dir_name+'/owaCDM_py_SN+HD+BBAO_mh_50000_1'
mcsamplefile = mcsamples.loadMCSamples(rootU, ini=None, jobItem=None, no_cache=False)
g = plots.getSubplotPlotter()
g.settings.figure_legend_frame = False
g.settings.alpha_filled_add=0.4
g.settings.title_limit_fontsize = 13
g.triangle_plot(mcsamplefile, ['Om', 'Obh2', 'h','w','wa','Ok'], 
    filled_compare=True, 
    contour_colors=['green'],title_limit=1)
#g.triangle_plot(mcsamplefile, 
#    filled_compare=True, 
#    contour_colors=['green'],title_limit=1)

# %%
g.settings.lab_fontsize = 12
g.settings.alpha_filled_add =0.5
g.settings.legend_fontsize=12
g.settings.axes_fontsize = 7

g.settings.auto_ticks
roots2 = ['owaCDM_SN+BBAO+RiessH0_mnest_0.6']
g.triangle_plot(roots2, ['Om', 'Obh2', 'h','w','wa','Ok'], 
                filled=False, nx=1, alphas=[0.7], colors=['black'],
               legend_labels=['MULTINEST'], 
                normalized=True, shaded=False)

#plt.savefig('samplersTriangleBAMBI.png')

# %% [markdown]
# # Probando análisis con Getdist

# %%
#filename = '/home/isidro/SuperMC/chains/owaChains2/owaCDM_py_SN+HD+BBAO_mh_50000_1'
#filename = dir_name+'/owaCDM_py_SN+BBAO+RiessH0_mh_20000_1'
filename = '/home/isidro/SuperMC/chains/LCDM_py_SN+HD+BBAO_mh_50000_1'
filename2 = '/home/isidro/SuperMC/chains/owaCDM_SN+HD+BBAO_mnest_0.6'

# %% [markdown]
# Generate a MCSample object

# %%
mcsamplefile = mcsamples.loadMCSamples(filename, ini=None, jobItem=None, no_cache=False)

# %%
mcsamplefile.PCA(['Om', 'Obh2', 'h','w','wa','Ok'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4bd65694302c> in <module>
# ----> 1 mcsamplefile.PCA(['Om', 'Obh2', 'h','w','wa','Ok'])
#
# NameError: name 'mcsamplefile' is not defined

# %% [markdown]
# # Covariance matrix of a MCSample object

# %%
mcsamplefile.cov(pars=['Om', 'Obh2', 'h','w','wa','Ok'])
# Out:
# array([[ 4.45005358e-04,  2.02431213e-07,  2.20101254e-04,
#          9.02634928e-04, -2.21557834e-03, -9.60905949e-04],
#        [ 2.02431213e-07,  2.10780497e-07,  8.83602339e-07,
#          5.92964158e-06, -7.90059951e-06, -2.22997308e-06],
#        [ 2.20101254e-04,  8.83602339e-07,  3.95337812e-04,
#          1.39802688e-04, -1.43573336e-03, -7.68874306e-04],
#        [ 9.02634928e-04,  5.92964158e-06,  1.39802688e-04,
#          8.48323815e-03, -1.05180717e-02, -5.91667971e-03],
#        [-2.21557834e-03, -7.90059951e-06, -1.43573336e-03,
#         -1.05180717e-02,  5.05248433e-02,  5.30100071e-03],
#        [-9.60905949e-04, -2.22997308e-06, -7.68874306e-04,
#         -5.91667971e-03,  5.30100071e-03,  6.67294974e-03]])

# %%
density1d = mcsamplefile.get1DDensity('Om')
density1d.bounds()
# Out:
# [0.24859787992171606, 0.40828712007828394]

# %%
mcsamplefile.std('Om')
# Out:
# 0.016415795196026924

# %%
mcsamplefile.getMeans()
# Out:
# array([  0.33015101,   0.02216679,   0.71428385,  -0.85800195,
#         -0.2841731 ,  -0.18108709, -17.22670188,  -0.17661018,
#         -2.66093735,  -1.09950819,  -0.9795427 ,  -0.01931026,
#         -1.11889233,  -0.83141808,  -0.54897549])

# %%
mcstats = mcsamplefile.getLikeStats()

# %%
mcstats.likeSummary()
# Out:
# 'Best fit sample -log(Like) = 32.198500\nLn(mean 1/like) = 38.725731\nmean(-Ln(like)) = 34.889515\n-Ln(mean like)  = 34.130775\n'

# %%
mcstats.list()
# Out:
# ['Om',
#  'Obh2',
#  'h',
#  'w',
#  'wa',
#  'Ok',
#  'BetouleSN_like',
#  'HD_like',
#  'DR11LOWZ_like',
#  'DR11CMASS_like',
#  'DR11LyaAuto_like',
#  'DR11LyaCross_like',
#  'SixdFGS_like',
#  'MGS_like',
#  'theory_prior']

# %%
mcstats.names[0].ND_limit_top
# Out:
# array([0.357138, 0.366314])

# %%
mcstats.names[0].ND_limit_bot
# Out:
# array([0.269526, 0.261069])

# %%
mcstats.names[0].bestfit_sample
# Out:
# 0.302676

# %%
for i in range(6):
    print(mcstats.list()[i])
    top = mcstats.names[i].ND_limit_top[1]
    low = mcstats.names[i].ND_limit_bot[1]
    best = mcstats.names[i].bestfit_sample
    #print(top)
    #print(low)
    print("best %4.5f"%(best))
    print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
    print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
    print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
# Out:
# Om
# best 0.30268
# mean 0.31003
# 0.303 + 0.064 - 0.042
# std dev 0.0164
# Obh2
# best 0.02203
# mean 0.02203
# 0.022 + 0.001 - 0.001
# std dev 0.0004
# h
# best 0.67603
# mean 0.67284
# 0.676 + 0.070 - 0.067
# std dev 0.0198
# w
# best -0.82169
# mean -0.79508
# -0.822 + 0.247 - 0.248
# std dev 0.0706
# wa
# best 0.16801
# mean -0.16993
# 0.168 + 0.332 - 1.066
# std dev 0.2958
# Ok
# best -0.24161
# mean -0.18034
# -0.242 + 0.331 - 0.226
# std dev 0.1097

# %%
 print(mcsamplefile.getMeans())
# Out:
# [  0.33015101   0.02216679   0.71428385  -0.85800195  -0.2841731
#   -0.18108709 -17.22670188  -0.17661018  -2.66093735  -1.09950819
#   -0.9795427   -0.01931026  -1.11889233  -0.83141808  -0.54897549]

# %%
mcsample.saveAsText('testtext')

# %%
mcsample.savePickle('pickletext')

# %%
#filename = '/home/isidro/SuperMC/chains/owaChains2/owaCDM_SN+HD+BBAO_mnest_0.6'
filename = '/home/isidro/SuperMC/chains/owaChains2/LCDM_py_SN+HD+BBAO_mh_50000_1'
filename2 = '/home/isidro/SuperMC/chains/LCDM_SN+HD+BBAO_mnest_0.6'
mcsamplefile = mcsamples.loadMCSamples(filename, ini=None, jobItem=None, no_cache=False)
mcstats = mcsamplefile.getLikeStats()
for i in range(3):
    print(mcstats.list()[i])
    top = mcstats.names[i].ND_limit_top[1]
    low = mcstats.names[i].ND_limit_bot[1]
    best = mcstats.names[i].bestfit_sample
    #print(top)
    #print(low)
    print("best %4.5f"%(best))
    print("mean %4.5f"%(mcsamplefile.getMeans()[i]))
    print("%4.3f + %4.3f - %4.3f"%(best, (top-best), (best-low)))
    print("std dev %5.4f"%(mcsamplefile.std(mcstats.list()[i])))
# Out:
# Om
# best 0.28589
# mean 0.28673
# 0.286 + 0.031 - 0.028
# std dev 0.0104
# Obh2
# best 0.02208
# mean 0.02199
# 0.022 + 0.001 - 0.001
# std dev 0.0005
# h
# best 0.66717
# mean 0.66790
# 0.667 + 0.027 - 0.024
# std dev 0.0091

# %%
file = "/home/isidro/SuperMC/chains/generic_generic_mnest_0.5"
mcsamplefile = mcsamples.loadMCSamples(file, ini=None, jobItem=None, no_cache=False)
#g = plots.getSubplotPlotter()

# %%
g.settings.lab_fontsize = 16
g.settings.alpha_filled_add =0.5
g.settings.legend_fontsize=16
g.settings.axes_fontsize = 16

g.settings.auto_ticks
g.triangle_plot(mcsamplefile, ['b', 'a'], 
    filled_compare=True, 
    contour_colors=['green'],title_limit=1)
plt.savefig("line.png")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
#import planckStyle
import pylab
import numpy as np

# %%
dir_name = '/home/isidro/SuperMC/chains/'
sample2 = '/home/isidro/SimpleMC/chains/LCDM_SN+BBAO+RiessH0+Planck_snest_0.1.txt'
roots = ['owaCDM_py_SN+RiessH0+BBAO_mh_10000_1', 'owaCDM_SN+RiessH0+BBAO_snest_0.1', 'owaCDM_SN+RiessH0+BBAO_mnest_0.1',
        'owaCDM_SN+RiessH0+BBAO_sbambi_0.1','owaCDM_SN+RiessH0+BBAO_bambi_0.1'] 
rootsdl = ['owaCDM_py_SN+RiessH0+BBAO_mh_10000_1', 'owaCDM_SN+RiessH0+BBAO_mnest_0.1',
        'owaCDM_SN+RiessH0+BBAO_bambi_0.1'] 

root = ['owaCDM_SN+RiessH0+BBAO_mnest_0.1']
nledroot = ['nled_SN+RiessH0+BBAO_bambi_0.1']

# %%
g= plots.getSinglePlotter(chain_dir = dir_name, width_inch=10, 
                          analysis_settings={'smooth_scale_2D': 0.6, 'ignore_rows': 0.2})

# %%
#g.settings.axes_fontsize = 8
#g.settings.lab_fontsize = 12
g.settings.alpha_filled_add =0.5
g.settings.auto_ticks
#g.plot_2d(root,'Om','Obh2', filled=False, nx=1, alphas=[0.9], colors=['blue','red'])
g.plot_2d(roots,'Om','Obh2', filled=False, nx=1, alphas=[0.9])
#g.add_text('$k_{eq}=0.0152$', x=0.27, y=0.15, fontsize =13)
g.add_legend(['mh', 'snest','mnest','sbambi','bambi'], 
             colored_text=True,  legend_loc='upper right')
#plt.savefig('a.png')
# Out:
# ---------------------------------------------------------------------------
# GetDistPlotError                          Traceback (most recent call last)
# <ipython-input-4-8dd4bd2bbe90> in <module>
#       4 g.settings.auto_ticks
#       5 #g.plot_2d(root,'Om','Obh2', filled=False, nx=1, alphas=[0.9], colors=['blue','red'])
# ----> 6 g.plot_2d(roots,'Om','Obh2', filled=False, nx=1, alphas=[0.9])
#       7 #g.add_text('$k_{eq}=0.0152$', x=0.27, y=0.15, fontsize =13)
#       8 g.add_legend(['mh', 'snest','mnest','sbambi','bambi'],
#
# /usr/local/lib/python3.6/dist-packages/getdist/plots.py in plot_2d(self, roots, param1, param2, param_pair, shaded, add_legend_proxy, line_offset, proxy_root_exclude, **kwargs)
#    1151             param_pair = param1
#    1152             param1 = None
# -> 1153         param_pair = self.get_param_array(roots[0], param_pair or [param1, param2])
#    1154         if self.settings.progress: print('plotting: ', [param.name for param in param_pair])
# ...

# %%
g.settings.axes_fontsize = 7
g.settings.lab_fontsize = 10
g.settings.alpha_filled_add =0.5

#root = ['LCDM_SN+BBAO+RiessH0+Planck_snest_0.1'] 
#g.triangle_plot(root, filled=False, nx=1, alphas=[0.9], colors=['black','red'], 
#                legend_labels=['sin RNA', 'con RNA'])
#
g.triangle_plot(nledroot, filled=True, nx=1, alphas=[0.9], color='red', shaded=True)

#plt.savefig('triangleOwaCDMMH.png')
# Out:
# ---------------------------------------------------------------------------
# GetDistPlotError                          Traceback (most recent call last)
# <ipython-input-5-d22502e2c943> in <module>
#       7 #                legend_labels=['sin RNA', 'con RNA'])
#       8 #
# ----> 9 g.triangle_plot(nledroot, filled=True, nx=1, alphas=[0.9], color='red', shaded=True)
#      10
#      11 #plt.savefig('triangleOwaCDMMH.png')
#
# /usr/local/lib/python3.6/dist-packages/getdist/plots.py in triangle_plot(self, roots, params, legend_labels, plot_3d_with_param, filled, shaded, contour_args, contour_colors, contour_ls, contour_lws, line_args, label_order, legend_ncol, legend_loc, upper_roots, upper_kwargs, diag1d_kwargs, param_limits, **kwargs)
#    1951         """
#    1952         roots = makeList(roots)
# -> 1953         params = self.get_param_array(roots[0], params)
#    1954         plot_col = len(params)
# ...

# %%
#g.settings.axes_fontsize = 5
g.settings.auto_ticks
g.settings.lab_fontsize = 10
g.settings.alpha_filled_add =0.5
g.settings.legend_fontsize=10
g.triangle_plot(roots, ['Om', 'Obh2', 'h','w','wa','Ok'], 
                filled=False, nx=1, alphas=[0.9], colors=['red','blue','black','green','yellow'],
               legend_labels=['MH', 'ENS', 'MULTINEST', 'ENS+ANN', 'BAMBI'], 
                normalized=True, shaded=True)

#plt.savefig('samplersTriangle2.png')
# Out:
# ---------------------------------------------------------------------------
# GetDistPlotError                          Traceback (most recent call last)
# <ipython-input-6-626307a6b54d> in <module>
#       7                 filled=False, nx=1, alphas=[0.9], colors=['red','blue','black','green','yellow'],
#       8                legend_labels=['MH', 'ENS', 'MULTINEST', 'ENS+ANN', 'BAMBI'],
# ----> 9                 normalized=True, shaded=True)
#      10
#      11 #plt.savefig('samplersTriangle2.png')
#
# /usr/local/lib/python3.6/dist-packages/getdist/plots.py in triangle_plot(self, roots, params, legend_labels, plot_3d_with_param, filled, shaded, contour_args, contour_colors, contour_ls, contour_lws, line_args, label_order, legend_ncol, legend_loc, upper_roots, upper_kwargs, diag1d_kwargs, param_limits, **kwargs)
#    1951         """
#    1952         roots = makeList(roots)
# -> 1953         params = self.get_param_array(roots[0], params)
#    1954         plot_col = len(params)
# ...

# %%
g.settings.lab_fontsize = 12
g.settings.alpha_filled_add =0.5
g.settings.legend_fontsize=12
g.settings.axes_fontsize = 7

g.settings.auto_ticks

g.triangle_plot(roots, ['Om', 'Obh2', 'h','w','wa','Ok'], 
                filled=False, nx=1, alphas=[0.9], colors=['red','blue','black','green','yellow'],
               legend_labels=['MH', 'MULTINEST', 'BAMBI'], 
                normalized=True, shaded=True)

plt.savefig('samplersTriangleBAMBI.png')

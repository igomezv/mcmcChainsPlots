# %%
import matplotlib.pyplot as plt
from getdist import plots, MCSamples, chains
from getdist import *

import pylab

import numpy as np
import matplotlib
import tkinter
import pandas as pd

matplotlib.use('TkAgg')

# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/getdist/plots.py:10: MatplotlibDeprecationWarning: The 'warn' parameter of use() is deprecated since Matplotlib 3.1 and will be removed in 3.3.  If any parameter follows 'warn', they should be pass as keyword, not positionally.
#   matplotlib.use('Agg', warn=False)

# %%
dir_name = '/home/isidro/SimpleMC/chains'

roots = ['owaCDM_phy_HD+SN+BBAO+Planck_nested_dynesty_multi', 'owaCDM_phy_HD+SN+BBAO+Planck_nested_dynesty_multi_ANN']

# %%
g= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.4,
                                             'smooth_scale_1D': 0.4, 
                                             'ignore_rows': 0.2})

# %%
g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 8
g.settings.legend_fontsize = 8
g.settings.axes_fontsize = 8

g.triangle_plot(roots, ['Om', 'Obh2', 'h', 'w', 'wa', 'Ok'], 
                diag1d_kwargs={'colors':['red','blue']},
                colors=['red','blue', 'green'],
                legend_labels=['dynesty only 50 live points', 'bambi 2 hidden layers, 200 neurons'], 
                filled = False, 
                normalized=True, shaded=False)
        
#plt.savefig(dir_name+'owaCDMBambi.png', dpi=300)
plt.show()

# %%
# roots2 = ['respaldoUAMnotebook/LCDM_phy_SN+HD+BBAO+Planck_nested_dynesty_multii', 
#           #'LCDM_phy_SN+HD+BBAO+Planck_nested_dynesty_multi',
#           'respaldoUAMnotebook/LCDM_phy_SN+HD+BBAO+Planck_nested_dynesty_multi_ANN_new']
roots2 = ['LCDM_phy_HD+SN+BBAO+Planck_nested_dynesty_multi_ANN_new']

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.1})
g.settings.axes_fontsize = 8
g.settings.lab_fontsize = 12
g.settings.legend_fontsize = 14
g.settings.axes_fontsize = 8

g.triangle_plot(roots2, ['Om', 'Obh2', 'h'], 
                diag1d_kwargs={'colors':['red','blue', 'green']},
                colors=['red','blue', 'green'],
                legend_labels=['nested sampling', #'bambi 2 hidden layers, 200 neurons, 0.5 proxy',
                               'nested sampling with ANN'], 
                filled = False, 
                normalized=True, shaded=False)
        
#plt.savefig(dir_name+'LCDMBambi.png', dpi=300)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/getdist/chains.py:1149: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   weights = None if self.chains[0].weights is None else np.hstack((chain.weights for chain in self.chains))
# /usr/local/lib/python3.6/dist-packages/getdist/chains.py:1150: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   loglikes = None if self.chains[0].loglikes is None else np.hstack((chain.loglikes for chain in self.chains))
# ...

# %%
roots2 = ['owaCDM_phy_BBAO+SN+HD+Planck_nested_dynesty_multi',
          
          'owaCDM_phy_BBAO+SN+HD+Planck_nested_dynesty_multi_ANN'
          ]
#owaCDM_phy_BBAO+SN+HD+Planck_mcmc_new

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 12,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.1,
                                             'smooth_scale_1D': 0.1, 
                                             'ignore_rows': 0.1})
g.settings.axes_fontsize = 8
g.settings.lab_fontsize =12
g.settings.legend_fontsize = 14
g.settings.axes_fontsize = 7

g.triangle_plot(roots2, ['Om', 'Obh2', 'h', 'w', 'wa', 'Ok'], 
                diag1d_kwargs={'colors':['red','blue', 'green', 'purple']},
                colors=['red','blue', 'green', 'purple'],
                legend_labels=['nested', 'nested with ann',
                               'mcmc', #'bambi 2 hidden layers, 200 neurons, 0.5 proxy',
                               'mcmc with ann'], 
                filled = False, 
                normalized=True, shaded=False)
        
plt.savefig(dir_name+'CPLBambi.png', dpi=300)
plt.show()
# Out:
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# WARNING:root:fine_bins_2D not large enough for optimal density
# ...

# %%
roots2 = ['LCDM_phy_BBAO+SN+HD+Planck_nested_dynesty_multi',
          
          'LCDM_phy_BBAO+SN+HD+Planck_nested_dynesty_multi_ANN'
          ]
#owaCDM_phy_BBAO+SN+HD+Planck_mcmc_new

# %%
g = plots.getSinglePlotter(chain_dir = dir_name, width_inch= 12,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.3,
                                             'smooth_scale_1D': 0.3, 
                                             'ignore_rows': 0.1})
g.settings.axes_fontsize = 8
g.settings.lab_fontsize =12
g.settings.legend_fontsize = 14
g.settings.axes_fontsize = 7

g.triangle_plot(roots2, ['Om', 'Obh2', 'h'], 
                diag1d_kwargs={'colors':['red','blue', 'green', 'purple']},
                colors=['red','blue', 'green', 'purple'],
                legend_labels=['nested', 'nested with ann',
                               'mcmc', #'bambi 2 hidden layers, 200 neurons, 0.5 proxy',
                               'mcmc with ann'], 
                filled = False, 
                normalized=True, shaded=False)
        
#plt.savefig(dir_name+'CPLBambi.png', dpi=300)
plt.show()

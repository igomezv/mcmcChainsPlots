# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
#import planckStyle
import pylab
import numpy as np

# %%
dir_name = '/home/isidro/SuperMC/chains/'
sample2 = '/home/isidro/SimpleMC/chains/LCDM_SN+BBAO+RiessH0+Planck_snest_0.1.txt'
roots = ['LCDM_SN+BBAO+RiessH0+Planck_snest_0.1','LCDM_SN+BBAO+RiessH0+Planck_sbambi_0.1'] 
root = ['LCDM_py_SN+RiessH0_mh_5000_1']

# %%
g= plots.getSinglePlotter(chain_dir = dir_name, width_inch=8, 
                          analysis_settings={'smooth_scale_2D': 0.6, 'ignore_rows': 0.2})

# %%
g.settings.axes_fontsize = 10
g.settings.lab_fontsize = 15
g.settings.alpha_filled_add =0.5
g.plot_2d(roots,'Om','Obh2', filled=False, nx=1, alphas=[0.9], colors=['blue','red'])
#g.add_text('$k_{eq}=0.0152$', x=0.27, y=0.15, fontsize =13)
g.add_legend(['sin RNA', 'con RNA'], 
             colored_text=True,  legend_loc='upper right')
#plt.savefig('a.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/getdist/chains.py:1149: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   weights = None if self.chains[0].weights is None else np.hstack((chain.weights for chain in self.chains))
# /usr/local/lib/python3.6/dist-packages/getdist/chains.py:1150: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   loglikes = None if self.chains[0].loglikes is None else np.hstack((chain.loglikes for chain in self.chains))
# ...

# %%
g.settings.axes_fontsize = 10
g.settings.lab_fontsize = 15
g.settings.alpha_filled_add =0.5
root = ['LCDM_SN+BBAO+RiessH0+Planck_snest_0.1'] 
#g.triangle_plot(root, filled=False, nx=1, alphas=[0.9], colors=['black','red'], 
#                legend_labels=['sin RNA', 'con RNA'])
g.triangle_plot(root, filled=True, nx=1, alphas=[0.9], colors=['red'])
             
#plt.savefig('triangle.png')

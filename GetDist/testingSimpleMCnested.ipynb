# %%
import matplotlib.pyplot as plt
from getdist import plots, MCSamples, chains
from getdist import *

#import planckStyle
import pylab

import numpy as np
import matplotlib
import tkinter
import pandas as pd

matplotlib.use('TkAgg')

# %matplotlib inline

# %%
#dir_name = '/home/isidro/SuperMC/chains/owaChains1'
#dir_name = '/home/isidro/SuperMC_fork_20nov/april/chains'
dir_name = '/home/isidro/SimpleMC/chains'

#roots = ['LCDM_phy_BBAO+HD_emcee_20_walkers',
#         'LCDM_phy_BBAO+HD_nested_dynesty_multi', 
#        'LCDM_phy_BBAO+HD_mcmc']
#,
roots = ['LCDM_phy_HD_nested_dynesty_multi']
         #'owaCDM_phy_BBAO+HD_nested_dynesty_multi'
         
        
#, 
#        
# roots = ['owaCDM_phy_BBAO+HD_nested_dynesty_multi']

# %%
g= plots.getSinglePlotter(chain_dir = dir_name, width_inch= 10,
                          ratio = 0.9, 
                          analysis_settings={'smooth_scale_2D': 0.5,
                                             'smooth_scale_1D': 0.5, 
                                             'ignore_rows': 0.2})

# %%
#g.settings.axes_fontsize = 5
g.settings.lab_fontsize = 15
g.settings.legend_fontsize = 12
g.settings.axes_fontsize = 12

g.triangle_plot(roots, ['Om', 'Obh2', 'h'], 
                diag1d_kwargs={'colors':['red','blue']},
                colors=['red','blue', 'green'],
                legend_labels=['emcee', 'dynest'], 
                filled = False, 
                normalized=True, shaded=False)
        

#plt.savefig('CPLBBAOHDemceeVSdynesty.png', dpi=300)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/getdist/chains.py:1149: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   weights = None if self.chains[0].weights is None else np.hstack((chain.weights for chain in self.chains))
# /usr/local/lib/python3.6/dist-packages/getdist/chains.py:1150: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   loglikes = None if self.chains[0].loglikes is None else np.hstack((chain.loglikes for chain in self.chains))
# ...

# %%
from MCEvidence import MCEvidence

# %%
emceetxt = dir_name + '/owaCDM_phy_UnionSN+HD+BBAO+Planck_emcee_20_walkers.txt'

# nestedtxt = 'LCDM_phy_BBAO+HD_nested_dynesty_multi_1.txt'

mcmctxt = dir_name + '/mcmc_SN+HD+BBAO+Planck.txt'

# %%
MLE = MCEvidence(emceetxt).evidence()
# Out:
# INFO:MCEvidence:Loading chain from /home/isidro/SimpleMC/SimpleMC/chainsServer/owaCDM_phy_UnionSN+HD+BBAO+Planck_emcee_20_walkers.txt
# INFO:MCEvidence:loading: /home/isidro/SimpleMC/SimpleMC/chainsServer/owaCDM_phy_UnionSN+HD+BBAO+Planck_emcee_20_walkers.txt
# INFO:MCEvidence:chain array dimensions: [3920] x 6 =
# INFO:MCEvidence:Estimating covariance matrix using all chains
# INFO:MCEvidence:covariance matrix estimated using nsample=3920
# INFO:MCEvidence:getting samples for partition s1: nsamples=3920
# INFO:MCEvidence:   ln(B)[k=1] = -74.48544286943306
# INFO:MCEvidence:   ln(B)[k=2] = -74.42860035930184
# INFO:MCEvidence:   ln(B)[k=3] = -74.38491764728826
# INFO:MCEvidence:   ln(B)[k=4] = -74.34406464579266

# %%
MLE3 = MCEvidence(mcmctxt).evidence()
# Out:
# INFO:MCEvidence:Loading chain from /home/isidro/SimpleMC/SimpleMC/chainsServer/mcmc_SN+HD+BBAO+Planck.txt
# INFO:MCEvidence:loading: /home/isidro/SimpleMC/SimpleMC/chainsServer/mcmc_SN+HD+BBAO+Planck.txt
# INFO:MCEvidence:chain array dimensions: [508000] x 16 =
# INFO:MCEvidence:Estimating covariance matrix using all chains
# INFO:MCEvidence:covariance matrix estimated using nsample=508000
# INFO:MCEvidence:getting samples for partition s1: nsamples=508000
# /usr/local/lib/python3.6/dist-packages/MCEvidence.py:847: RuntimeWarning: invalid value encountered in true_divide
#   s[:,i]= s[:,i]/math.sqrt(eigenVal[i])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2b99d89f69ea> in <module>
# ----> 1 MLE3 = MCEvidence(mcmctxt).evidence()
#
# ...
